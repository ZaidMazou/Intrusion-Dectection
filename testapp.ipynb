# %%
import requests
import json

# %%
def test_integration(log):
    response = send_log_to_ml_server(log)
    print(f"Log: {log}, Prediction: {response}")

# Test avec des logs simulés
test_log = {'features': [0.1, 0.2, 0.3, 0.4]}
test_integration(test_log)
